# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Daniel Gross**
# I wish to get into the alternative fuels insudtry from an high-tech perspective

# %% [markdown]
# _I'm interested in data science because I have good analytical skills but poor tools to use. I wish this course will helo me improve my skills_

# %% [markdown]
# ### My code is supposed to count family members that come for dinner. The value "1" means they gonna come. The value "0" means they don't.
# ### If all are coming I will join.

# %%
Dad = 1
Mom = 1
Sister = 1
Brother = 0


if (Dad + Mom + Sister + Brother) < 4:
    print("I'm not coming to dinner")
else: 
    print ("I'm coming to dinner")
# Out:
# I'm not coming to dinner

# %% [markdown]
# Meals in a day and those I ate:
#
# ___
# ___
# 1. Breakfast
# 2. ~~Lunch~~
# 3. ~~Dinner~~
#
# |Time of meal |Breakfast|Lunch|Dinner|
# |:-----------:|:-------:|:---:|:----:|
# |7-10         |    X    |     |      |
# |11-14        |         |X    |      |
# |17-21        |         |     |  X   |
#
# ___
# ___
# <div>
# <img src="attachment:2022-11-20%2018_29_40-.png" width="300"/>
# </div>
